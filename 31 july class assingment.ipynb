# %% [markdown]
# # Task 1 - Fitbit Dataset
#
# 1. Read this dataset in pandas , mysql and mongodb
#
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
#
#  ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql
#
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
#
# 4 . Find out in this data that how many unique id's we have
#
# 5 . which id is one of the active id that you have in whole dataset
#
# 6 . how many of them have not logged there activity find out in terms of number of ids
#
# 7 . Find out who is the laziest person id that we have in dataset
#
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset
#
# 9.  how many person are not a regular person with respect to activity try to find out those
#
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
#
# 11 . who is the 5th most laziest person avilable in dataset find it out
#
# 12 . what is a totla acumulative calories burn for a person find out

# %% [markdown]
# # task 2 - Superstore_USA
# 1 . load this data in sql and in pandas with a relation in sql
#
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
#
# 3 . Find out how return that we ahve recived and with a product id
#
# 4 . try  to join order and return data both in sql and pandas
#
# 5 . Try to find out how many unique customer that we have
#
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
#
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
#
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
#
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
#
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
#
# 11 . Gorup by region and find out which region is more profitable
#
# 12 . Try to find out overalll in which country we are giving more didscount
#
# 13 . Give me a list of unique postal code
#
# 14 . which customer segement is more profitalble find it out .
#
# 15 . try to find out the 10th most loss making product catagory .
#
# 16 . Try to find out 10 top  product with highest margins
#
# submit your git link for the same
#
# you have to submit this task by next Friday 5th 11PM IST  to respective mail id
# sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %%
import pandas as pd
import numpy as np

# %%
fitbit=pd.read_csv("D:\Python_data\FitBit data.csv",parse_dates=["ActivityDate"])

# %%
fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
type(fitbit["ActivityDate"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# 2. while creting a table in mysql dont use manual approach to create it ,always use a automation to create a table in mysql
# ans. I used "https://www.convertcsv.com/csv-to-sql.htm" website for creating table automated.(some changes you can do according to your requerments)
CREATE TABLE fitbit(
   Id                       VARCHAR(30)
  ,ActivityDate varchar(255)
  ,TotalSteps               INTEGER 
  ,TotalDistance            INTEGER 
  ,TrackerDistance          VARCHAR(19)
  ,LoggedActivitiesDistance VARCHAR(17)
  ,VeryActiveDistance       VARCHAR(19)
  ,ModeratelyActiveDistance VARCHAR(18)
  ,LightActiveDistance      VARCHAR(19)
  ,SedentaryActiveDistance  VARCHAR(19)
  ,VeryActiveMinutes        INTEGER 
  ,FairlyActiveMinutes      INTEGER 
  ,LightlyActiveMinutes     INTEGER 
  ,SedentaryMinutes         INTEGER 
  ,Calories                 INTEGER 
);

update fitbit
set ActivityDate=date_format(ActivityDate,"%d/%m/%y"); # for changing into date format


INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,'3/25/2016',11004,7.1100001335144,'7.1100001335144','0','2.5699999332428','0.46000000834465','4.07000017166138','0',33,12,205,804,1819);
INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,'3/26/2016',17609,11.5500001907349,'11.5500001907349','0','6.92000007629395','0.730000019073486','3.91000008583069','0',89,17,274,588,2154);
INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,'3/27/2016',12736,8.52999973297119,'8.52999973297119','0','4.65999984741211','0.159999996423721','3.71000003814697','0',56,5,268,605,1944);
INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,'3/28/2016',13231,8.93000030517578,'8.93000030517578','0','3.19000005722046','0.790000021457672','4.94999980926514','0',39,20,224,1080,1932);
INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,'3/29/2016',12041,7.84999990463257,'7.84999990463257','0','2.16000008583069','1.0900000333786','4.6100001335144','0',28,28,243,763,1886);
INSERT INTO fitbit(Id,ActivityDate,TotalSteps,TotalDistance,TrackerDistance,LoggedActivitiesDistance,VeryActiveDistance,ModeratelyActiveDistance,LightActiveDistance,SedentaryActiveDistance,VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes,Calories) VALUES (1503960366,
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'D:\Python_data\FitBit data.csv'
jsonFilePath = r'D:\Python_data\FitBit_data.json'
csv_to_json(csvFilePath, jsonFilePath)

# %%
# create connection
import pymongo
client = pymongo.MongoClient("mongodb+srv://himanshu:mongodb@testing-cluster.t5jsa.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db
# Out:
# Database(MongoClient(host=['testing-cluster-shard-00-02.t5jsa.mongodb.net:27017', 'testing-cluster-shard-00-01.t5jsa.mongodb.net:27017', 'testing-cluster-shard-00-00.t5jsa.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-ss5xto-shard-0', tls=True), 'test')

# %%
db = client["database31july"]
collection = db["fitbit_data"]

# %%
# Loading or Opening the json file
with open('D:\Python_data\FitBit_data.json') as file:
    file_data = json.load(file)

# %%
collection.insert_many(file_data)

# %%
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# Ans. converted in timestamp at time of pd.read_csv with parse_dates option. and in sql I defined in create table as date

# %%
#4 . Find out in this data that how many unique id's we have 

print("there are %d unique id's in our dataset" % fitbit["Id"].nunique())
# Out:
# there are 35 unique id's in our dataset

# %%
#5 . which id is one of the active id that you have in whole dataset 

# Ans. for this quetion we will see that which id run maximum step on an average

avg_step=fitbit.groupby("Id")["TotalSteps"].agg([np.mean, np.sum , lambda x: x.count()])
avg_step.index[avg_step["mean"]==max(avg_step["mean"])][0]
# Out:
# 8877689391

# %%
# 6 . how many of them have not logged there activity find out in terms of number of ids 

# Ans. we can find out this via LoggedActivitiesDistance is 0 but it may be possible that a id have LoggedActivitiesDistance but he or she is not do any walking(i.e. steps can be zero.)


not_logged=fitbit["Id"][(fitbit["LoggedActivitiesDistance"]==0)&(fitbit["TotalSteps"]!=0)].unique()
l=[]
for i in range(len(not_logged)):
    l.append(not_logged[i])
print(" There are total %d Ids which have not logged there activity" %len(l), " and there list are given below: \n", l)
# Out:
#  There are total 33 Ids which have not logged there activity  and there list are given below:
#  [1503960366, 1624580081, 1644430081, 1844505072, 1927972279, 2022484408, 2026352035, 2320127002, 2347167796, 2873212765, 3372868164, 3977333714, 4020332650, 4057192912, 4319703577, 4445114986, 4558609924, 4702921684, 5553957443, 5577150313, 6117666160, 6290855005, 6391747486, 6775888955, 6962181067, 7007744171, 7086361926, 8053475328, 8253242879, 8378563200, 8583815059, 8792009665, 8877689391]

# %%
# 7 . Find out who is the laziest person id that we have in dataset

# %%
fitbit["Id"][fitbit["TotalSteps"]==min(fitbit["TotalSteps"].values)].unique().tolist()
# Out:
# [1844505072,
#  2320127002,
#  2347167796,
#  2873212765,
#  2891001357,
#  4057192912,
#  4319703577,
#  4388161847,
#  4702921684,
#  6117666160,
#  6290855005,
#  6391747486,
#  6775888955,
#  8253242879]

# %%
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
def calori(x):
    if x < 500:
        return "Need to Burn More"
    elif x>1000:
        return "Over Burn"
    else:
        return "Healty"
fitbit["Calorie_status"]=fitbit["Calories"].apply(calori)
fitbit["Calorie_status"].value_counts()
# Out:
# Over Burn            430
# Healty                15
# Need to Burn More     12
# Name: Calorie_status, dtype: int64

# %%
# 9. how many person are not a regular person with respect to activity try to find out those 

fitbit["ActivityDate"].describe()

# TWe have 32 days data have present .so if any person works 32 days or near to 32 days so we can say that that man is regular person
# Out:
# C:\Users\Himanshu\AppData\Local\Temp\ipykernel_2996\3502953865.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   fitbit["ActivityDate"].describe()
# count                     457
# unique                     32
# top       2016-04-02 00:00:00
# freq                       35
# first     2016-03-12 00:00:00
# last      2016-04-12 00:00:00
# Name: ActivityDate, dtype: object

# %%
x=fitbit.groupby("Id")["Id"].count()
x.index[x.values==max(x.values)].values
# Out:
# array([4020332650, 4057192912], dtype=int64)

# %%
# or this can also be show by
fitbit["Id"].value_counts()[fitbit["Id"].value_counts()==max((fitbit["Id"].value_counts()).values)]
# Out:
# 4057192912    32
# 4020332650    32
# Name: Id, dtype: int64

# %%
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .

# %%
x=pd.DataFrame(fitbit["Id"].value_counts().sort_values(ascending=False))
x.rename(columns = {'Id':'count'}, inplace = True)
x['Rank'] = x["count"].rank(method='dense',ascending=False).astype(int)

# %%
x[x["Rank"]==3].index.values
# Out:
# array([2347167796, 4702921684, 4445114986], dtype=int64)

# %%
# for SQL the query will be
select Id 
from 
(select * , dense_rank() over(order by count desc) count_rank
from 
(select Id,count(*) as count from fitbit
group by Id
order by count desc) sub) sub1
where count_rank=3;

# %%
# 11 . who is the 5th most laziest person avilable in dataset find it out
x['Rank'] = x["count"].rank(method='dense',ascending=True).astype(int)
x[x["Rank"]==5].index.values
# Out:
# array([5553957443, 4319703577, 1927972279, 3977333714, 2873212765,
#        2022484408, 1844505072, 8877689391, 2026352035, 7007744171,
#        7086361926, 8253242879, 8378563200, 8792009665, 4558609924,
#        2320127002], dtype=int64)

# %%
# 12 . what is a totla acumulative calories burn for a person find out

# %%
fitbit["cumlative_calorie"]=fitbit["Calories"].cumsum()

# %%
fitbit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# Ans. I am not able to understand this 12th quetion

# %% [markdown]
# # task 2 - Superstore_USA

# %%
# 1 . load this data in sql and in pandas with a relation in sql
orders=pd.read_excel("D:\Python_data\Superstore_USA.xlsx",sheet_name='Orders')
returns=pd.read_excel("D:\Python_data\Superstore_USA.xlsx",sheet_name='Returns')
users=pd.read_excel("D:\Python_data\Superstore_USA.xlsx",sheet_name='Users')

# %%
orders['Order Date']=pd.to_datetime(orders['Order Date'])
orders['Ship Date']=pd.to_datetime(orders['Ship Date'])

# %%
# 1 . load this data in sql with a relation in sql
orders.to_csv(r"D:\Python_data\orders.csv",)
returns.to_csv(r"D:\Python_data\returns.csv")
users.to_csv(r"D:\Python_data\users.csv")


# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# I used Import data wizard option for load data into mysql and table setting option for making primary and foreign key.
SET GLOBAL FOREIGN_KEY_CHECKS=0;
SET FOREIGN_KEY_CHECKS=0;
ALTER TABLE `ineuron`.`orders` 
ADD INDEX `Order ID_idx` (`Order ID` ASC) VISIBLE;
;
ALTER TABLE `ineuron`.`orders` 
ADD CONSTRAINT `Order ID`
  FOREIGN KEY (`Order ID`)
  REFERENCES `ineuron`.`returns` (`Order ID`)
  ON DELETE NO ACTION
  ON UPDATE NO ACTION;
  ALTER TABLE `ineuron`.`orders` 
ADD INDEX `Region_idx` (`Region` ASC) VISIBLE;
;
ALTER TABLE `ineuron`.`orders` 
ADD CONSTRAINT `Region`
  FOREIGN KEY (`Region`)
  REFERENCES `ineuron`.`users` (`Region`)
  ON DELETE NO ACTION
  ON UPDATE NO ACTION;

# %% [markdown]
# ![erd.png](attachment:erd.png)

# %%
# 4 . try to join order and return data both in sql and pandas
orders=orders.merge(returns,how="left",on="Order ID")
orders=orders.merge(users,how="left",on="Region")
orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# 4 . try to join order and return data both in sql
select o.*,r.Status,u.Region from orders o
left join returns r on o.`Order ID`=r.`Order ID`
left join users u on o.`Region`=u.`Region`;

# %%
# 3 . Find out how return that we have recived and with a product id
orders["Status"].value_counts()

# Ans. so we can say that there are 98 rowID or Product ID we have recived return
# Out:
# Returned    98
# Name: Status, dtype: int64

# %%
# 5 . Try to find out how many unique customer that we have 
orders["Customer ID"].nunique()
# Out:
# 2703

# %%
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
orders.groupby(['Product Category','Region','Manager'])['Region'].count()
# Out:
# Product Category  Region   Manager
# Furniture         Central  Chris       623
#                   East     Erin        479
#                   South    Sam         370
#                   West     William     461
# Office Supplies   Central  Chris      1559
#                   East     Erin       1272
#                   South    Sam        1099
#                   West     William    1251
# Technology        Central  Chris       717
#                   East     Erin        538
#                   South    Sam         485
#                   West     William     572
# Name: Region, dtype: int64

# %%
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
orders['Ship Mode'].value_counts(normalize=True).mul(100)

# Ans. So we can see that there are 3 different types of shipement mode and their percentage is give below
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %%
# 8 . Create a new coulmn and try to find out a diffrence between order date and shipment date

orders["date_diff"]=orders["Ship Date"]-orders["Order Date"]
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   Postal Code Order Date  Ship Date    Profit Quantity ordered new    Sales  \
# ...

# %%
orders["date_diff"]=orders["date_diff"].dt.days

# %%
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
orders['Order ID'][orders["date_diff"]>10].unique()
# Out:
# array([87215, 86318, 87957, 19556, 86177, 88223, 88352, 87572, 91294,
#        86434, 86436, 87300, 19841], dtype=int64)

# %%
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
orders[['Order ID','Manager']][(orders["Status"]=="Returned") & (orders["date_diff"]>15)]

# Ans. no such records found
# Out:
# Empty DataFrame
# Columns: [Order ID, Manager]
# Index: []

# %%
# 11 . Gorup by region and find out which region is more profitable
orders.groupby('Region')['Profit'].agg([np.mean, np.sum , lambda x: x.count()])
# ans so we can see that Central region is more profitable
# Out:
#                mean            sum  <lambda_0>
# Region
# Central  179.312027  519825.567067        2899
# East     164.948094  377566.186045        2289
# South     53.327120  104201.192420        1954
# West     136.098710  310849.453897        2284

# %%
# 12 . Try to find out overalll in which country we are giving more discount

x=orders.groupby('State or Province')['Discount'].agg([ lambda x: (x.mean())*100, np.sum , lambda x: x.count()])
x.sort_values("<lambda_0>",ascending=False)
# Out:
#                       <lambda_0>    sum  <lambda_1>
# State or Province
# Wyoming                 5.476190   1.15          21
# Louisiana               5.460674   4.86          89
# Rhode Island            5.450000   1.09          20
# Utah                    5.253425   7.67         146
# Minnesota               5.238494  12.52         239
# Vermont                 5.229508   3.19          61
# Connecticut             5.219512   4.28          82
# Maine                   5.203125   6.66         128
# Kansas                  5.180451   6.89         133
# Tennessee               5.150602   8.55         166
# California              5.120470  52.28        1021
# Arizona                 5.119403   6.86         134
# Kentucky                5.096386   4.23          83
# Illinois                5.087329  29.71         584
# South Carolina          5.085714   5.34         105
# Indiana                 5.070539  12.22         241
# Massachusetts           5.054054  11.22         222
# ...

# %%
# 13 . Give me a list of unique postal code
x=orders['Postal Code'].unique()

l=[]
for i in x:
    l.append(i)
l
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status', 'Manager',
#        'date_diff'],
#       dtype='object')

# %%
# 14 . which customer segement is more profitalble find it out .
x=orders.groupby("Customer Segment")["Profit"].mean()
x[x==x.max()]
# Out:
# Customer Segment
# Small Business    171.903635
# Name: Profit, dtype: float64

# %%
# 15 . try to find out the 10th most loss making product catagory . hint: take Product Sub-Category on place of Product Category
x=orders.groupby("Product Sub-Category")["Profit"].mean().sort_values()
x[x==x[9]]
# Out:
# Product Sub-Category
# Office Furnishings    104.427209
# Name: Profit, dtype: float64

# %%
# 16 . Try to find out top 10 product with highest margins 
orders.groupby("Product Name")["Product Base Margin"].mean().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers    0.85
# Accessory27                                                                   0.85
# Sterling Rubber Bands by Alliance                                             0.85
# Belkin OmniView SE Rackmount Kit                                              0.85
# Accessory4                                                                    0.85
# Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand              0.84
# Tennsco Commercial Shelving                                                   0.84
# Serrated Blade or Curved Handle Hand Letter Openers                           0.84
# Accessory36                                                                   0.83
# Eldon Shelf Savers™ Cubes and Bins                                            0.83
# Name: Product Base Margin, dtype: float64
